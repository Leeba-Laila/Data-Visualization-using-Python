# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Countplot
#  * A count plot can be thought of as a histogram across a categorical instead of quantitative variable
#  * x-axis has a categorical variable and y-axis has count of each category

# %%
sns.countplot(x='smoker', data = tips_df)
plt.show()

# %%
sns.countplot(y='smoker', data=tips_df)
plt.show()

# %%
sns.countplot(y='smoker', data=tips_df, hue = 'day')
plt.show()

# %%
sns.countplot(x='sex', data = tips_df)
plt.show()

# %%
sns.countplot(x='day', data = tips_df)
plt.show()

# %%
sns.countplot(y='day', data = tips_df)
plt.show()

# %%
sns.countplot(x='time', data = tips_df)
plt.show()

# %%
sns.countplot(x='size', data = tips_df)
plt.show()

# %% [markdown]
# ### Boxplot
# * Box plot conveys the distribution of values, the maximum and median values.
# * Box plot is used for a numeric variable (univariate Analysis)
# * Draw a box plot to show distributions with respect to categories.(Bivariate Analysis)

# %% [markdown]
# ### Box plot and Whiskers
# *The Concept of median, percentile, quantile, whiskers
# *A box and whisker plot—also called a box plot—displays the five-number summary of a set of data.
# *The five-number summary is the minimum, first quartile, median, third quartile, and maximum. In a box plot
# *Box plots may also have lines extending from the boxes indicating variability outside the upper and lower quartiles

# %%
#Univariate Analysis with a boxplot

sns.boxplot(x = 'total_bill', data = tips_df)
plt.show()

# %%
#Univariate Analysis with a boxplot

sns.boxplot(x = 'tip', data = tips_df)
plt.show()

# %%
#Univariate Analysis with a boxplot

sns.boxplot(y = 'tip', data = tips_df)
plt.show()

# %% [markdown]
# - By default, the x axis is considered as the categorical data and y as numerical data.
# - If two numerical values are to be plotted, we have to mention the discrete value on x axis and continuos value on y axis

# %%
#Bivariate Analysis with a boxplot(Continuous vs Categorical)
#Relationship between categorical and continuous variable 

sns.boxplot(x = 'tip', y = 'day', data = tips_df)
plt.show()

# %%
sns.boxplot(x = 'tip', y = 'day', data = tips_df, palette='spring')
plt.show()

# %%
#Whether there is any relationship between smoking and total bill

sns.boxplot(x = 'total_bill', y = 'smoker', data = tips_df, palette = 'Blues')
plt.show()

# %%
sns.boxplot(x = 'tip', y = 'smoker', data = tips_df)
plt.show()

# %% [markdown]
# - If both variables are numeric and we don't specify orient, by default it takes x axis as categorical and y as continuous

# %%
#Here we cannot get a proper plot since both the x and y values are numerical data.
#Boxplot works only for the combination of categorical and numerical data

sns.boxplot(x = 'tip', y = 'size', data = tips_df)
plt.show()

# %%
#Here when the orient is given as 'h', we mention that the median has to be calculated on the tip and not on size.
#So even if specify  x as tip and y as size since we specify the orient, it would calculate median for tip.

sns.boxplot(x='tip', y='size', data=tips_df, palette='spring', orient='h')
plt.show()

# %%
#

sns.boxplot(x = 'size', y = 'tip', data = tips_df)
plt.show()

# %% [markdown]
# ### Joint Plot :
# * The joint plot allows us to draw a plot of two variables with bivariate and univariate graphs.
# * Draw multiple bivariate plots with univariate marginal distributions.
# * We can also specify the kind of plots with the ‘kind’ keyword argument.
# * Kind must be either ‘scatter’, ‘reg’, ‘resid’, or ‘hex’.

# %%
#In this case, we get a view of univariate analysis(barplot) and Bi-variate analysis(scatterplot)

sns.jointplot(x = 'total_bill', y = 'tip', data = tips_df, kind = 'scatter')
plt.show()

# %% [markdown]
# - Residue isthe difference between the the actual value and the value from the line

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips_df, kind = 'reg')
plt.show()

#According to my regression line, the tip for $50 is somewhere near $6. But when I consider the scatterplot, 
#the tip for $50 is showing somewhere near to $10. This difference between the actual data(ie, data from scatterplot 
#which is 10) and the data from the line(ie, data from the regression line which is $6) is called the residue. This shows 
#the error margin

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips_df, kind = 'resid')
plt.show()

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips_df, kind = 'hex')
plt.show()

# %% [markdown]
# ### Pair Plot:
# * One of the simplest ways to visualize the relation between all features, the pair plot method. *plots all the pair relationships in the dataset at once. *The method takes all the features in the dataset and plots it against each other

# %%
sns.pairplot(tips_df)
plt.show()

# %% [markdown]
# ### HeatMap and PairPlot are the plots that helps us to look into the relationship between the data.

# %% [markdown]
# # Correlation with heatmap
#
# - Heatmap helps us to find and visualize correlation between each and every feature
# - Correlation values lies between -1 and 1
# - if -1, the data are negatively correlated
# - if 1, the data are positively correlated
# - if value more than 0.5, then the data is highly correlated. If less than 0.5, the data is less correlated.

# %%
print(tips_df.corr())
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_df.corr())
plt.show()

# %%
#annot helps to print the data on top of the map in each box

sns.heatmap(tips_df.corr(), annot = True, cmap = 'RdBu')
plt.show()

# %% [markdown]
# ### Colormap	Description
# -    Blues	white to dark blue
# -    BuGn	white, light blue, dark green
# -    BuPu	white, light blue, dark purple
# -    GnBu	white, light green, dark blue
# -    Greens	white to dark green
# -    Greys	white to black (not linear)
# -    Oranges	white, orange, dark brown
# -    OrRd	white, orange, dark red
# -    PuBu	white, light purple, dark blue
# -    PuBuGn	white, light purple, dark green
# -    PuRd	white, light purple, dark red
# -    Purples	white to dark purple
# -    RdPu	white, pink, dark purple
# -    Reds	white to dark red
# -    YlGn	light yellow, dark green
# -    YlGnBu	light yellow, light green, dark blue
# -    YlOrBr	light yellow, orange, dark brown
# -    YlOrRd	light yellow, orange, dark red
#
#
# ### Link
# - https://www.kite.com/python/docs/matplotlib.pyplot.colormaps

# %% [markdown]
# ### Violin plot
# * It is a combination of boxplot and kernel density distribution
# * Show the relationship between a nuerical and categorical data

# %%
#Shows the relationship between total bill and day

sns.violinplot(x = 'total_bill', y = 'day', data = tips_df)
plt.show()

# You have a boxplot inside the violinplot. The data beyond the whiskers of the boxplot inside the violinplot specifies 
#the outliers. This also shows how the data is distributed. Also shows the min ans max values. Therefore violinplot 
#is also used in the industry.

# %%
#Shows the relationship between tip and day

sns.violinplot(x = 'tip', y = 'day', data = tips_df)
plt.show()

# %%
#Shows the relationship between size and total bill

sns.violinplot(x = 'size', y = 'total_bill', data = tips_df)
plt.show()

# %%
#Shows the relationship between sex and total bill

sns.violinplot(x = 'sex', y = 'total_bill', data = tips_df)
plt.show()

# %% [markdown]
# # Using new dataset iris

# %% [markdown]
# ### The iris dataset contains the following data
# * 50 samples of 3 different species of iris (150 samples total)
# * Measurements: sepal length, sepal width, petal length, petal width
# * The format for the data: (sepal length, sepal width, petal length, petal width)
# * Each value we are predicting is the response (also known as: target, outcome, label, dependent
# * variable) Classification is supervised learning in which the response is categorical
# * "0": setosa
# * "1": versicolor
# * "2": virginica

# %%
iris_df = pd.read_csv(r'C:\Users\91730\Desktop\Python_DFz\iris.csv')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Comparison between Seaborn and Matplotlib

# %% [markdown]
# ### Histogram

# %%
#Using Seaborn Histogram

sns.distplot(iris_df['sepal_length'], 30, kde=True)   #Histogram plot
plt.show()
# Out:
# C:\Users\91730\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Matplotlib

plt.hist(iris_df['sepal_length'], 10,  rwidth = 0.9)
plt.show()

# %%
#Using the dataframe

iris_df['sepal_length'].hist(bins=30)
plt. xlabel('sepal_length')
plt.ylabel('frequency')
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
new = iris_df.drop(['species'], axis = 1)
new
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
new.hist(bins = 10, figsize = (10,10))
plt.show()

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x = 'sepal_length', data = iris_df)
plt.show()

# %%
sns.boxplot(x = 'petal_length', data = iris_df)
plt.show()

# %%
new.boxplot()
plt.show()

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(x = 'petal_length', data = iris_df)
plt.show()

# %%
sns.violinplot(x ='petal_length', y = 'species', data = iris_df)
plt.show()

# %%
sns.violinplot(x ='species', y = 'petal_length', data = iris_df)
plt.show()

# %% [markdown]
# ### Subplot

# %%
figsize = (16,10)
plt. subplot(2,2,1)
plt.plot(iris_df['sepal_length'], label = 'sepal length')
plt.subplot(2,2,2)
plt.plot(iris_df['sepal_width'], label = 'sepal width')
plt.subplot(2,2,3)
plt.plot(iris_df['petal_length'], label = 'petal length')
plt.subplot(2,2,4)
plt.plot(iris_df['petal_width'], label = 'petal length')
plt.show()

# %%
figsize = (16,10)
plt.subplot(2,2,1)
plt.plot(iris_df['sepal_length'], label = 'sepal length')
plt.legend()
plt.subplot(2,2,2)
plt.plot(iris_df['sepal_width'], label = 'sepal width')
plt.legend()
plt.subplot(2,2,3)
plt.plot(iris_df['petal_length'], label = 'petal length')
plt.legend()
plt.subplot(2,2,4)
plt.plot(iris_df['petal_width'], label = 'petal length')
plt.legend()
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(x ='sepal_length', y = 'sepal_width', data = iris_df)
plt.show()

# %%
sns.scatterplot(x ='sepal_length', y = 'sepal_width', hue= 'species', data = iris_df)
plt.show()

# %%
sns.scatterplot(x ='petal_length', y = 'petal_width', data = iris_df)
plt.show()

# %%
sns.scatterplot(x ='petal_length', y = 'petal_width', hue= 'species', data = iris_df)
plt.show()

# %%
#Matplotlib

plt.scatter(x ='petal_length', y = 'petal_width', data = iris_df)
plt.show()

# %% [markdown]
# ### Jointplot

# %%
sns.jointplot(x ='petal_length', y = 'petal_width', data = iris_df)
plt.show()

# %%
sns.jointplot(x ='petal_length', y = 'petal_width', data = iris_df, kind = 'scatter')
plt.show()

# %%
sns.jointplot(x ='sepal_length', y = 'petal_width', data = iris_df)
plt.show()

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iris_df)
plt.show()

# %%
sns.pairplot(iris_df, hue = 'species')
plt.show()

# %% [markdown]
# ### HeatMap

# %%
sns.heatmap(iris_df.corr(), annot = True, cmap = 'YlGn')
plt.show()

# %% [markdown]
# ### Regressionplot

# %%
sns.regplot(x='petal_length', y='petal_width',  data=iris_df, color='red',marker='D')
plt.show()

# %%
#Comparison

sns.violinplot(x="species", y="petal_width", data=iris_df)
plt.show()

# %%
#Comparison

sns.boxplot(x = "species", y = "petal_width", data = iris_df)
plt.show()

# %%
sns.countplot(x = 'species', data = iris_df)
plt.show()

# %%
sns.catplot(x = "species", y = "petal_width", data = iris_df)
plt.show()
